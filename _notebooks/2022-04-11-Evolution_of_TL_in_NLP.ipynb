# %% [markdown]
# # Evolution of Transfer Learning in Natural Language Processing [WIP]
# > An overview covering important NLP milestones from pre transfer learning era to the latest happenings in transfer learning
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [Transfer Learning in NLP]
# - image: images/transfer_learning_evolution/Transfer_learning_evolution_pic_1.png
# - hide: false

# %% [markdown]
# ## 1. Quick Introduction

# %% [markdown]
# ### What is powering the emergence of better models in NLP?
# - Better representation of the text data (with no supervision) by grasping the `context` better
#      - From `Word2Vec` to `BERT` and beyond, this is the underlying logic!
#
# <hr>
#
# ### How are better text representations produced?
# - Better contextual representation of words using Transfer Learning
#
# <hr>
#
# ### What is Transfer Learning in NLP?
# ![](https://humboldt-wi.github.io/blog/img/seminar/group4_ULMFiT/Figure_1.png)
# Source: ULMFiT Paper | [link](https://humboldt-wi.github.io/blog/research/information_systems_1819/group4_ulmfit/)
#
# <hr>
#
# ### What forms the crux of Transfer Learning models in NLP?
# - Language Models! <br>
#     - (1) Build a **Language Model** that understands the underlying features of the text
#     - (2) Fine-tune the Language Model with additional layers for downstream tasks
#
# <hr>
#
# ### Why Language Model?
# > *Language modeling can be seen as the ideal source task as it captures many facets of language relevant for downstream tasks, such as long-term dependencies, hierarchical relations and sentiment* <br>
# >
# >Ruder et al in the ULMFiT paper
#
# <hr>
#
# ### Ok, What is a Language Model?
# - A language model (LM) is a model that generates a probability distribution over sequences of words
# - In simpler words, LM is a model to predict the next word in a sequence of words
#
# <hr>
#
# ### What are those Language Models?
# - Word2Vec, Glove, ELMo, ULMFiT, BERT, and many more
#
# ![](https://ruder.io/content/images/2021/02/pretraining_finetuning.png)
# Source: A article by Sebastian Ruder: `State of Transfer Learning in NLP` | [Link](https://ruder.io/state-of-transfer-learning-in-nlp/)
#
# <hr>
#
# ### In short, How has transfer learning evolved in NLP?
#
# - Step -2: NLP started with rule-based and statistical methodologies
# - Step -1: ML algorithms such as Naive Bayes, SVM, LR and Trees coupled which where fed with bag-of-words word representations
# - Step 0: Initial Success of better representations using shallow Neural Network pre-trained LMs like Word2Vec
# - Step 1: (Re)Emergence of RNN Architectures in NLP
# - Step 2: Evolution of Sequence-to-Sequence Models built with RNN architectures from Language Models | [source](https://indicodata.ai/blog/sequence-modeling-neuralnets-part1/)
# - Step 3: `ImageNet` moment in NLP called upon by the first pre-Transformer era Transfer Learning models - ULMFiT and ELMo
# - Step 4: Cometh the era of Attention and Transformers
#
# ![](transfer_learning_evolution/Seq2Seq_Model_A_Higher_form_of_LM.png)

# %% [markdown]
# ## 2. Introduction to Language Modeling

# %% [markdown]
# ## 3. Evolution of RNN Architecture till LSTM + Attention

# %% [markdown]
# ## 4. Transformer (Attention without LSTM )

# %% [markdown]
# ## 5. The advent of BERT - Pre-trained Transformer-based LMs

# %% [markdown]
# ## 6. Conclusion
# ### Why Transformers are awesome?
# ### But what do they lack?
# ### What is the future of Pre-trained Transformer LM

# %% [markdown]
# References:
# - A suevey paper on `Evolution of Transfer Learning in Natural Language Processing` | [Link](https://arxiv.org/pdf/1910.07370.pdf)
# - A survey paper on `Pre-trained Models for NLP` | [Link](https://arxiv.org/pdf/2003.08271.pdf)
# - `The State of Transfer Learning in NLP` | Article by Sebastian Ruder | [Link](https://ruder.io/state-of-transfer-learning-in-nlp/)
# - `NLP's ImageNet Moment has arrived` | Article by Sebastian Ruder | [Link](https://ruder.io/nlp-imagenet/)
# - `Recent Advances in LMs` | Article by Sebastian | [Link](https://ruder.io/recent-advances-lm-fine-tuning/)
# - `Sequence Modeling with Neural Networks`
#      - [Part 1](https://indicodata.ai/blog/sequence-modeling-neuralnets-part1/): `Evolution of Seq2Seq Models from Language Models`
#      - [Part 2](https://indicodata.ai/blog/sequence-modeling-neural-networks-part2-attention-models/): `Seq2Seq with Attention`
# - `LSTM is dead. Long Live Transformers`  | [YouTube Video by Leo Dirac](https://www.youtube.com/watch?v=S27pHKBEp30&t=1073s) |  [Presentation on the same title](https://rbouadjenek.github.io/papers/transformers_Reda@Deakin.pdf)
