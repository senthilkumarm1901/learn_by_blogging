# %% [markdown]
# # Part I - Build Serverless ML Pipeline using AWS Lambda and Step Functions
# > This blog post explains how to leverage S3, Lambda, StepFunctions, Docker, aws CLI and boto3 to build a Speech Diarization and Recognition pipeline
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [aws]
# - image: images/aws/aws_main_logo.png
# - hide: false

# %% [markdown]
# Dataset to use:
# - https://huggingface.co/datasets/ami

# %% [markdown]
# WIP
