# %% [markdown]
# # Part II - Build Containerized ML Application using AWS Fargate
# > This blog post explains how to leverage open source tools for building a Speech Diarization and Speech2Text application using AWS Fargate
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [aws]
# - image: images/aws/aws_main_logo.png
# - hide: false

# %% [markdown]
# Dataset to use:
# - https://huggingface.co/datasets/ami

# %% [markdown]
# WIP
