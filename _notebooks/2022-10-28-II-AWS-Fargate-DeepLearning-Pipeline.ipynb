# %% [markdown]
# # Part II - Build Containerized ML Application using AWS Fargate
# > This blog post explains How to leverage open source tools for building a production-grade Speech Diarization and Speech2Text System using AWS Fargate
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [aws]
# - image: images/aws/aws_main_logo.png
# - hide: false

# %% [markdown]
# WIP
