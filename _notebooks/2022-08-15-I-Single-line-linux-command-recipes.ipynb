# %% [markdown]
# # Part I - Highly Useful Linux Command Line Recipes
# > This blog post provides single line linux recipes for most common tasks for any software engineer
#
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [linux]
# - image: images/linux/linux_main_logo.jpeg
# - hide: false

# %% [markdown]
# ## Introduction to Linux
# - What is a Linux Machine?
# - What language does Linux uses internally?
# - Linux vs Unix:
# - Different Linux Distributions
# - Many Names: Linux CLI (OR) Shell (OR) Terminal (OR) Command Prompt
# - Linux and Shell Scripting (TV and Remote)

# %% [markdown]
# ## Surpirisingly Simple Single-line Commands
# - cat | head & tail | head, tail, and wc -l
# - ls | xargs | mkdir
# - find
# - grep
# - sed

# %%
## Really Good Linux CLI Recipies
-

# %% [markdown]
# Some Selected Good Data Processing Recipies for Linux (Shell scripting) vs Python Comparison: <br>
# 1. Find files with a regex pattern | Look for specific string using grep (find, grep)
# 2. Make a list of dir based on a column name in a csv file (cat, awk, mkdir)
# 3. Suppose there are 100 files in a dir and you need to zip 10 at a time (zip)
# 4. Processing a csv file of gb size | Do a Regex String replacement (sed)
