# %% [markdown]
# # Part II - A Gentle Introduction to the World of Shell Scripting
# > This blog gives a gentle introduction to some useful features of Unix style Shell Scripting and how it is applied in makefile, dockerfile and git commands
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [linux]
# - image: images/linux/linux_main_logo.jpeg
# - hide: false

# %% [markdown]
# WIP
