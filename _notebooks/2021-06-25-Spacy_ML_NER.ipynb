# %% [markdown]
# # How to train a Spacy NER Model_WIP
# > In this blog post, I cover the process of creating trained ML NER model from Unlabeled data
# - toc: true
# - branch: master
# - author: Senthil Kumar
# - badges: true
# - comments: true
# - categories: [spacy/NER]
# - image: images/spacy/spacy_ML_model_training_on_unlabeld_data.png
# - hide: false

# %% [markdown]
# <hr>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# **How do we create ML NER Model from no labeled data?**:
#
# - Prepare rules-bootstrapped training data from unlabeled corpus
# - Rules-boostrapped data reviewed/edited by human annotator and - Train & Evaluate an optimized ML NER model

# %% [markdown]
# ## 2. Rules-bootstrapped Data + Human Reviewed data

# %% [markdown]
# ### 2A. Infer Spacy Rules NER as token-level results

# %% [markdown]
# ### 2B. Edit token-level results in csv

# %% [markdown]
# ### 2C. Convert token-level Results 2 Spacy Model-acceptable Data

# %% [markdown]
# ## 3. Train ML Model

# %% [markdown]
# ### 3A. Prepare a ML-trained Model from training

# %% [markdown]
# ## 4. Evaluate the model

# %% [markdown]
# ### 4A. Comparing the entity-level F1-score of (1) Rules, (2) Spacy small and (3) Spacy Roberta-base model

# %% [markdown]
# ## 5. Post Processing of ML Model

# %% [markdown]
# ### 5A. Write Rules on top of the ML-trained Model (to improve accuracy/ or capture some new entity)

# %% [markdown]
# ## 6. Conclusion
